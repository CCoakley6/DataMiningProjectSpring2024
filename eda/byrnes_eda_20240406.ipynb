# %%
import pandas as pd
import glob
import numpy as np

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)
# Out:
# /tmp/ipykernel_17181/286112891.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
columns_to_load = [
     'location_key'
    , 'date'
    , 'place_id'
    , 'wikidata_id'
    , 'datacommons_id'
    , 'country_code'
    , 'country_name'
    , 'subregion1_code'
    , 'subregion1_name'
    , 'subregion2_code'
    , 'subregion2_name'
    , 'new_confirmed'
    , 'new_deceased'
    , 'cumulative_confirmed'
    , 'cumulative_deceased'
    , 'new_persons_fully_vaccinated'
    , 'cumulative_persons_fully_vaccinated'
    , 'population'
    , 'population_male'
    , 'population_female'
    , 'population_age_00_09'
    , 'population_age_10_19'
    , 'population_age_20_29'
    , 'population_age_30_39'
    , 'population_age_40_49'
    , 'population_age_50_59'
    , 'population_age_60_69'
    , 'population_age_70_79'
    , 'population_age_80_and_older'
    , 'openstreetmap_id'
    , 'latitude'
    , 'longitude'
    , 'area_sq_km'
    , 'life_expectancy'
    , 'mobility_retail_and_recreation'
    , 'mobility_grocery_and_pharmacy'
    , 'mobility_parks'
    , 'mobility_transit_stations'
    , 'mobility_workplaces'
    , 'mobility_residential'
    , 'average_temperature_celsius'
    , 'minimum_temperature_celsius'
    , 'maximum_temperature_celsius'
    , 'rainfall_mm'
    , 'dew_point'
    , 'relative_humidity'
]

# %%
# Directory path to your CSV files
directory_path = "../Test CSVs/"  # Example directory path

# Initialize an empty DataFrame to store data from all CSV files
full_df = pd.DataFrame(columns=columns_to_load)

# Loop over the list of CSV files
for file in glob.glob(directory_path + '*.csv'):
    # Read the CSV file without specifying columns to ensure we don't miss any data
    df = pd.read_csv(file)
    
    # Ensure all desired columns are present, add them with NaN values if they are missing
    for column in columns_to_load:
        if column not in df.columns:
            df[column] = np.nan

    # Reorder and select only the desired columns to maintain consistency
    df = df[columns_to_load]
    
    # Append the contents of the file to the full DataFrame
    full_df = pd.concat([full_df, df], ignore_index=True)

# Optionally, reset the index of the final DataFrame
full_df.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipykernel_17181/2111723118.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)
# /tmp/ipykernel_17181/2111723118.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)

# %%
# Print each column name
for column in df.columns:
    print(column)
# Out:
# location_key
# date
# place_id
# wikidata_id
# datacommons_id
# country_code
# country_name
# subregion1_code
# subregion1_name
# subregion2_code
# subregion2_name
# new_confirmed
# new_deceased
# cumulative_confirmed
# cumulative_deceased
# new_persons_fully_vaccinated
# cumulative_persons_fully_vaccinated
# population
# population_male
# population_female
# population_age_00_09
# population_age_10_19
# population_age_20_29
# population_age_30_39
# population_age_40_49
# population_age_50_59
# population_age_60_69
# population_age_70_79
# population_age_80_and_older
# openstreetmap_id
# latitude
# longitude
# area_sq_km
# life_expectancy
# mobility_retail_and_recreation
# mobility_grocery_and_pharmacy
# mobility_parks
# mobility_transit_stations
# mobility_workplaces
# mobility_residential
# average_temperature_celsius
# minimum_temperature_celsius
# maximum_temperature_celsius
# rainfall_mm
# dew_point
# relative_humidity

# %%
full_df.shape
# Out:
# (411265, 46)

# %%
full_df.sample(n=20)
# Out:
#        location_key        date                     place_id wikidata_id  \
# 48651   US_FL_12059  2020-04-02  ChIJHbV_dTK3k4gR2mrWL_AIRMQ     Q488879
# 154226  US_CO_08101  2021-09-13  ChIJbSRz_4WvE4cRLsrDtfjKNkI     Q312731
# 307830  US_NY_36093  2021-09-12  ChIJl0U8cZtv3okRn7RP-8dPzb8     Q487599
# 384085  US_NC_37043  2021-07-22  ChIJrTGG8JbXXogRJ-R2LjJthrA     Q502516
# 45956   US_CA_06089  2021-01-05  ChIJuTsbyAyZ0lQRqcLKtOn5yus     Q156350
# 45159   US_CA_06095  2021-07-18  ChIJB_R9n88XhYAR-L8fjKYikj0     Q108083
# 395395  US_CA_06069  2022-09-04  ChIJ_8VcLuc7koARQXmgrXGnQxc     Q109656
# 34509   US_NY_36043  2022-03-26  ChIJyeOziPvA3okRBqScD7E9IDY     Q487564
# 162155  US_WI_55091  2021-09-14  ChIJfVMgitFa-IcR9bC2EPaJ8Xg     Q505868
# 85522   US_NC_37193  2020-10-23  ChIJJSbZxhULUYgRrDyDy-aeZlk     Q430328
# 317     US_NC_37149  2020-11-13  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 290469  US_CO_08019  2020-04-16  ChIJr3DC7TOla4cRP3Q6xF1Y7wU     Q112977
# 275844  US_WI_55085  2020-12-12  ChIJHVp4ie-uVU0RkL5_7Ew2G10     Q497424
# 360596  US_CO_08099  2022-05-13  ChIJMY_io4KfDocR8yD7iWJPkwE     Q175035
# 92941   US_WI_55093  2022-02-17  ChIJr6079t4e-IcRkKiETUG8pak     Q501575
# 73486   US_WI_55029  2020-06-01  ChIJ02GslY19HYgRHC2DTN_P07Q     Q490550
# 146763  US_WI_55031  2020-04-05  ChIJH4sTsTq3rVIRugzR5D7LJyA     Q494936
# 90412   US_FL_12097  2020-08-19  ChIJpdRpwtGX3YgRX3_mBdXs8Y0     Q501067
# 344827  US_WI_55115  2022-08-08  ChIJ_WPnaD71AYgRySeagRoUn_4     Q500838
# 360877  US_NY_36101  2020-06-02  ChIJAS8L6mha0IkR5lxwoqXwEXo      Q71100
#
#        datacommons_id country_code              country_name subregion1_code  \
# 48651     geoId/12059           US  United States of America              FL
# 154226    geoId/08101           US  United States of America              CO
# 307830    geoId/36093           US  United States of America              NY
# 384085    geoId/37043           US  United States of America              NC
# 45956     geoId/06089           US  United States of America              CA
# 45159     geoId/06095           US  United States of America              CA
# 395395    geoId/06069           US  United States of America              CA
# 34509     geoId/36043           US  United States of America              NY
# 162155    geoId/55091           US  United States of America              WI
# 85522     geoId/37193           US  United States of America              NC
# 317       geoId/37149           US  United States of America              NC
# 290469    geoId/08019           US  United States of America              CO
# 275844    geoId/55085           US  United States of America              WI
# 360596    geoId/08099           US  United States of America              CO
# 92941     geoId/55093           US  United States of America              WI
# 73486     geoId/55029           US  United States of America              WI
# 146763    geoId/55031           US  United States of America              WI
# 90412     geoId/12097           US  United States of America              FL
# 344827    geoId/55115           US  United States of America              WI
# 360877    geoId/36101           US  United States of America              NY
#
#        subregion1_name subregion2_code     subregion2_name  new_confirmed  \
# 48651          Florida           12059       Holmes County            0.0
# 154226        Colorado            8101       Pueblo County          203.0
# 307830        New York           36093  Schenectady County           31.0
# 384085  North Carolina           37043         Clay County            4.0
# 45956       California            6089       Shasta County          195.0
# 45159       California            6095       Solano County            0.0
# 395395      California            6069   San Benito County            NaN
# 34509         New York           36043     Herkimer County            6.0
# 162155       Wisconsin           55091        Pepin County            7.0
# 85522   North Carolina           37193       Wilkes County           18.0
# 317     North Carolina           37149         Polk County            2.0
# 290469        Colorado            8019  Clear Creek County            0.0
# 275844       Wisconsin           55085       Oneida County           13.0
# 360596        Colorado            8099      Prowers County            0.0
# 92941        Wisconsin           55093       Pierce County           21.0
# 73486        Wisconsin           55029         Door County            0.0
# 146763       Wisconsin           55031      Douglas County            0.0
# 90412          Florida           12097      Osceola County           56.0
# 344827       Wisconsin           55115      Shawano County            NaN
# 360877        New York           36101      Steuben County            1.0
#
#         new_deceased  cumulative_confirmed  cumulative_deceased  \
# 48651            0.0                   1.0                  0.0
# 154226           2.0               21568.0                448.0
# 307830           0.0               14885.0                213.0
# 384085           0.0                 924.0                 18.0
# 45956            1.0                8463.0                 79.0
# 45159            0.0               34635.0                263.0
# 395395           NaN                   NaN                  NaN
# 34509            0.0               13708.0                189.0
# 162155           0.0                1004.0                  7.0
# 85522            0.0                1624.0                 37.0
# 317              0.0                 426.0                 13.0
# 290469           0.0                  11.0                  0.0
# 275844           1.0                2660.0                 49.0
# 360596           0.0                2654.0                 51.0
# 92941            0.0               11304.0                 70.0
# 73486            0.0                  38.0                  3.0
# 146763           0.0                   7.0                  0.0
# 90412            1.0               10480.0                122.0
# 344827           NaN                   NaN                  NaN
# 360877           1.0                 242.0                 19.0
#
#         new_persons_fully_vaccinated  cumulative_persons_fully_vaccinated  \
# 48651                            NaN                                  NaN
# 154226                           0.0                              77724.0
# 307830                         167.0                              95468.0
# 384085                           9.0                               3163.0
# 45956                            NaN                                  NaN
# 45159                          429.0                             215265.0
# 395395                           NaN                                  NaN
# 34509                            5.0                              36066.0
# 162155                           0.0                               3158.0
# 85522                            NaN                                  NaN
# 317                              NaN                                  NaN
# 290469                           NaN                                  NaN
# 275844                           NaN                                  NaN
# 360596                           0.0                               5246.0
# 92941                           21.0                              18574.0
# 73486                            NaN                                  NaN
# 146763                           NaN                                  NaN
# 90412                            NaN                                  NaN
# 344827                           0.0                              22189.0
# 360877                           NaN                                  NaN
#
#        population population_male population_female population_age_00_09  \
# 48651       19427           10341              9086                 2061
# 154226     166283           82000             84283                20099
# 307830     154710           75448             79262                18185
# 384085      11004            5360              5644                  955
# 45956      179384           88164             91220                21358
# 45159      443511          220820            222691                54678
# 395395      60164           30121             30043                 8211
# 34509       62163           30718             31445                 6827
# 162155       7246            3680              3566                  839
# 85522       68489           33751             34738                 7239
# 317         20564            9902             10662                 1642
# 290469       9574            5034              4540                  825
# 275844      35236           17646             17590                 3212
# 360596      11998            6011              5987                 1715
# 92941       42016           20951             21065                 4508
# 73486       27454           13547             13907                 2271
# 146763      43328           21697             21631                 4715
# 90412      353623          174281            179342                46104
# 344827      40846           20450             20396                 4578
# 360877      96360           48046             48314                11010
#
#        population_age_10_19 population_age_20_29 population_age_30_39  \
# 48651                  2189                 2607                 2269
# 154226                22097                21521                20636
# 307830                19193                20335                19858
# 384085                 1154                  910                  992
# 45956                 21231                22028                21676
# 45159                 54448                62909                60923
# 395395                 9024                 7995                 8183
# 34509                  7759                 7236                 6769
# 162155                  821                  721                  758
# 85522                  8345                 7499                 7137
# 317                    2098                 1817                 1656
# 290469                  836                  931                 1133
# 275844                 3381                 3311                 3376
# 360596                 1805                 1432                 1378
# 92941                  6368                 6848                 4768
# 73486                  2719                 2328                 2539
# 146763                 5102                 5419                 5484
# 90412                 50445                49582                51449
# 344827                 5055                 4115                 4325
# 360877                11933                11016                11169
#
#        population_age_40_49 population_age_50_59 population_age_60_69  \
# 48651                  2517                 2701                 2438
# 154226                19206                21485                21130
# 307830                18856                22201                18317
# 384085                 1158                 1496                 2093
# 45956                 18992                24622                25163
# 45159                 53402                61037                52576
# 395395                 7654                 8105                 6120
# 34509                  7172                 9395                 8657
# 162155                  798                 1106                 1123
# 85522                  8744                10120                 9492
# 317                    2236                 3060                 3585
# 290469                 1375                 1710                 1705
# 275844                 3717                 5908                 6295
# 360596                 1258                 1513                 1527
# 92941                  4910                 5971                 4859
# 73486                  2817                 4229                 5367
# 146763                 5077                 6443                 6084
# 90412                 49265                43471                33097
# 344827                 4855                 6476                 5586
# 360877                11440                14444                12895
#
#        population_age_70_79 population_age_80_and_older openstreetmap_id  \
# 48651                  1697                         948          1210750
# 154226                12505                        7604          1411328
# 307830                10212                        7553          1428121
# 384085                 1550                         696          2528687
# 45956                 15905                        8409           396512
# 45159                 28368                       15170           396513
# 395395                 3134                        1738           396500
# 34509                  5096                        3252          1835283
# 162155                  655                         425          1796054
# 85522                  6476                        3437          2528756
# 317                    2738                        1732          2528735
# 290469                  813                         246           442310
# 275844                 3891                        2145           270661
# 360596                  850                         520           415767
# 92941                  2466                        1318          1795854
# 73486                  3379                        1805           270667
# 146763                 3198                        1806          1796961
# 90412                 20652                        9558           389023
# 344827                 3742                        2114           270645
# 360877                 7715                        4738          1837996
#
#         latitude  longitude area_sq_km  life_expectancy  \
# 48651      30.87     -85.81       1266        74.500000
# 154226     38.15    -104.51       6210        76.360784
# 307830     42.81     -74.07        543        78.841860
# 384085     35.06     -83.76        571        78.200000
# 45956      40.76    -122.04       9956        76.774468
# 45159      38.27    -121.94       2348        78.801124
# 395395     36.61    -121.08       3206        82.400000
# 34509      43.41     -74.96       3777        79.584211
# 162155     44.60     -92.00        644              NaN
# 85522      36.20     -81.17        757        76.476923
# 317        35.28     -82.17        618        79.485714
# 290469     39.69    -105.64       1027        82.900000
# 275844     45.70     -89.52       3201              NaN
# 360596     37.96    -102.40       4259        78.860000
# 92941      44.72     -92.42       1532              NaN
# 73486      45.02     -87.01       6138              NaN
# 146763     46.45     -91.91       3833              NaN
# 90412      28.06     -81.15       3901        79.132353
# 344827     44.79     -88.76       2355              NaN
# 360877     42.26     -77.39       3637        79.786207
#
#         mobility_retail_and_recreation  mobility_grocery_and_pharmacy  \
# 48651                            -25.0                            0.0
# 154226                            -1.0                           14.0
# 307830                            -7.0                            9.0
# 384085                             NaN                            NaN
# 45956                            -12.0                            8.0
# 45159                             -5.0                           -7.0
# 395395                            -6.0                            0.0
# 34509                             -6.0                          -17.0
# 162155                             NaN                            NaN
# 85522                             -4.0                            5.0
# 317                                NaN                            NaN
# 290469                             NaN                            NaN
# 275844                            -8.0                           15.0
# 360596                             NaN                            NaN
# 92941                              NaN                            NaN
# 73486                             17.0                            NaN
# 146763                           -45.0                          -19.0
# 90412                            -24.0                          -16.0
# 344827                            22.0                           27.0
# 360877                           -17.0                           15.0
#
#         mobility_parks  mobility_transit_stations  mobility_workplaces  \
# 48651              NaN                        NaN                -28.0
# 154226           -25.0                        1.0                -20.0
# 307830             NaN                       -2.0                -20.0
# 384085             NaN                        NaN                -19.0
# 45956             18.0                      -21.0                -23.0
# 45159              5.0                      -19.0                -15.0
# 395395            -3.0                        NaN                 -4.0
# 34509              NaN                      -52.0                -12.0
# 162155             NaN                        NaN                 -3.0
# 85522              NaN                        NaN                -21.0
# 317                NaN                        NaN                -14.0
# 290469             NaN                        NaN                -61.0
# 275844            47.0                        NaN                  7.0
# 360596             NaN                       26.0                 -3.0
# 92941              NaN                        NaN                 -6.0
# 73486              NaN                        NaN                -20.0
# 146763             NaN                        NaN                -31.0
# 90412              NaN                      -32.0                -37.0
# 344827             NaN                        NaN                -16.0
# 360877             NaN                       13.0                -32.0
#
#         mobility_residential  average_temperature_celsius  \
# 48651                    NaN                    14.512346
# 154226                   2.0                    21.250000
# 307830                   0.0                    19.177778
# 384085                   NaN                    24.488889
# 45956                    7.0                     4.650000
# 45159                    1.0                    21.938272
# 395395                  -2.0                    18.638889
# 34509                    3.0                     4.505556
# 162155                   NaN                    18.238889
# 85522                    3.0                    17.544444
# 317                      NaN                    17.700000
# 290469                   NaN                    -3.172222
# 275844                   NaN                    -3.605556
# 360596                   NaN                    18.027778
# 92941                    6.0                   -12.366667
# 73486                    NaN                    12.814815
# 146763                   NaN                     1.012346
# 90412                   11.0                    26.697531
# 344827                   5.0                    18.927778
# 360877                  10.0                    15.433333
#
#         minimum_temperature_celsius  maximum_temperature_celsius  rainfall_mm  \
# 48651                      6.975309                    23.524691     0.000000
# 154226                    11.611111                    31.361111     0.685800
# 307830                     9.872222                    25.005556     0.000000
# 384085                    18.688889                    31.250000     0.000000
# 45956                     -0.311111                    11.150000    13.913556
# 45159                     13.944444                    31.364198     0.000000
# 395395                    11.250000                    28.272222     0.000000
# 34509                      1.961111                     9.655556     2.257778
# 162155                    15.000000                    21.611111     5.238750
# 85522                     12.088889                    25.138889     0.197556
# 317                       13.366667                    23.055556     9.683750
# 290469                    -6.300000                     2.083333     4.572000
# 275844                    -5.477778                    -1.055556     0.000000
# 360596                     4.988889                    31.716667     0.000000
# 92941                    -18.322222                    -3.988889     0.000000
# 73486                      8.271605                    17.870370     0.907143
# 146763                    -6.283951                     9.425926     0.310444
# 90412                     23.388889                    32.104938     4.540250
# 344827                    14.883333                    22.955556    14.192250
# 360877                     7.494444                    21.772222     0.000000
#
#         dew_point  relative_humidity
# 48651    5.604938          55.209001
# 154226   6.092593          38.318053
# 307830  15.296296          78.089029
# 384085  19.800000          75.351880
# 45956    1.358025          80.888465
# 45159   11.600000          49.482905
# 395395   7.913580          57.950026
# 34509    1.038889          78.484370
# 162155  14.538889          79.061419
# 85522   14.550000          82.693822
# 317     13.423611          73.447535
# 290469  -5.234568          82.085557
# 275844  -7.027778          77.314024
# 360596  -3.759259          22.597474
# 92941  -18.922222          58.130044
# 73486    8.518519          70.985870
# 146763  -6.888889          56.039246
# 90412   22.923611          80.393100
# 344827  16.033333          83.538479
# 360877   6.571429          56.640396
