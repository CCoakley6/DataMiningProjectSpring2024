# %%
import pandas as pd
import glob
import numpy as np

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# %%
columns_to_load = [
     'location_key'
    , 'date'
    , 'place_id'
    , 'wikidata_id'
    , 'datacommons_id'
    , 'country_code'
    , 'country_name'
    , 'subregion1_code'
    , 'subregion1_name'
    , 'subregion2_code'
    , 'subregion2_name'
    , 'new_confirmed'
    , 'new_deceased'
    , 'cumulative_confirmed'
    , 'cumulative_deceased'
    , 'new_persons_fully_vaccinated'
    , 'cumulative_persons_fully_vaccinated'
    , 'population'
    , 'population_male'
    , 'population_female'
    , 'population_age_00_09'
    , 'population_age_10_19'
    , 'population_age_20_29'
    , 'population_age_30_39'
    , 'population_age_40_49'
    , 'population_age_50_59'
    , 'population_age_60_69'
    , 'population_age_70_79'
    , 'population_age_80_and_older'
    , 'openstreetmap_id'
    , 'latitude'
    , 'longitude'
    , 'area_sq_km'
    , 'life_expectancy'
    , 'mobility_retail_and_recreation'
    , 'mobility_grocery_and_pharmacy'
    , 'mobility_parks'
    , 'mobility_transit_stations'
    , 'mobility_workplaces'
    , 'mobility_residential'
    , 'average_temperature_celsius'
    , 'minimum_temperature_celsius'
    , 'maximum_temperature_celsius'
    , 'rainfall_mm'
    , 'dew_point'
    , 'relative_humidity'
]

# %%
# Directory path to your CSV files
directory_path = "../North Carolina ONLY/"  # Example directory path

# Initialize an empty DataFrame to store data from all CSV files
full_df = pd.DataFrame(columns=columns_to_load)

# Loop over the list of CSV files
for file in glob.glob(directory_path + '*.csv'):
    # Read the CSV file without specifying columns to ensure we don't miss any data
    df = pd.read_csv(file)
    
    # Ensure all desired columns are present, add them with NaN values if they are missing
    for column in columns_to_load:
        if column not in df.columns:
            df[column] = np.nan

    # Reorder and select only the desired columns to maintain consistency
    df = df[columns_to_load]
    
    # Append the contents of the file to the full DataFrame
    full_df = pd.concat([full_df, df], ignore_index=True)

# Optionally, reset the index of the final DataFrame
full_df.reset_index(drop=True, inplace=True)

# %%
# Print each column name
for column in df.columns:
    print(column)
# Out:
# location_key
# date
# place_id
# wikidata_id
# datacommons_id
# country_code
# country_name
# subregion1_code
# subregion1_name
# subregion2_code
# subregion2_name
# new_confirmed
# new_deceased
# cumulative_confirmed
# cumulative_deceased
# new_persons_fully_vaccinated
# cumulative_persons_fully_vaccinated
# population
# population_male
# population_female
# population_age_00_09
# population_age_10_19
# population_age_20_29
# population_age_30_39
# population_age_40_49
# population_age_50_59
# population_age_60_69
# population_age_70_79
# population_age_80_and_older
# openstreetmap_id
# latitude
# longitude
# area_sq_km
# life_expectancy
# mobility_retail_and_recreation
# mobility_grocery_and_pharmacy
# mobility_parks
# mobility_transit_stations
# mobility_workplaces
# mobility_residential
# average_temperature_celsius
# minimum_temperature_celsius
# maximum_temperature_celsius
# rainfall_mm
# dew_point
# relative_humidity

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only the columns with integer or float data types
numeric_df = full_df.select_dtypes(include=['int64', 'float64'])

# Compute the correlation matrix for the numeric columns
corr_matrix = numeric_df.corr()

plt.figure(figsize=(12, 10))  # Width, height in inches


# Now 'corr_matrix' contains the correlation between the numeric columns
sns.heatmap(corr_matrix, annot=True, fmt=".2f")
plt.show()
# plt.save(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = full_df.corr()

# Generate a heatmap
sns.heatmap(corr_matrix, annot=True, fmt=".2f")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Compute the correlation matrix
# ----> 5 corr_matrix = full_df.corr()
#       7 # Generate a heatmap
#       8 sns.heatmap(corr_matrix, annot=True, fmt=".2f")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'US_NC_37079'

# %%
full_df.shape
# Out:
# (411265, 46)

# %%
full_df.head(20)
# Out:
#    location_key        date                     place_id wikidata_id  \
# 0   US_NC_37149  2020-01-01  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 1   US_NC_37149  2020-01-02  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 2   US_NC_37149  2020-01-03  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 3   US_NC_37149  2020-01-04  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 4   US_NC_37149  2020-01-05  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 5   US_NC_37149  2020-01-06  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 6   US_NC_37149  2020-01-07  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 7   US_NC_37149  2020-01-08  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 8   US_NC_37149  2020-01-09  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 9   US_NC_37149  2020-01-10  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 10  US_NC_37149  2020-01-11  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 11  US_NC_37149  2020-01-12  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 12  US_NC_37149  2020-01-13  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 13  US_NC_37149  2020-01-14  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 14  US_NC_37149  2020-01-15  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 15  US_NC_37149  2020-01-16  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 16  US_NC_37149  2020-01-17  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 17  US_NC_37149  2020-01-18  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 18  US_NC_37149  2020-01-19  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
# 19  US_NC_37149  2020-01-20  ChIJhY2KLODfWYgRctyyjgQU9go     Q507892
#
#    datacommons_id country_code              country_name subregion1_code  \
# 0     geoId/37149           US  United States of America              NC
# 1     geoId/37149           US  United States of America              NC
# 2     geoId/37149           US  United States of America              NC
# 3     geoId/37149           US  United States of America              NC
# 4     geoId/37149           US  United States of America              NC
# 5     geoId/37149           US  United States of America              NC
# 6     geoId/37149           US  United States of America              NC
# 7     geoId/37149           US  United States of America              NC
# 8     geoId/37149           US  United States of America              NC
# 9     geoId/37149           US  United States of America              NC
# 10    geoId/37149           US  United States of America              NC
# 11    geoId/37149           US  United States of America              NC
# 12    geoId/37149           US  United States of America              NC
# 13    geoId/37149           US  United States of America              NC
# 14    geoId/37149           US  United States of America              NC
# 15    geoId/37149           US  United States of America              NC
# 16    geoId/37149           US  United States of America              NC
# 17    geoId/37149           US  United States of America              NC
# 18    geoId/37149           US  United States of America              NC
# 19    geoId/37149           US  United States of America              NC
#
#    subregion1_name subregion2_code  ... mobility_parks  \
# 0   North Carolina           37149  ...            NaN
# 1   North Carolina           37149  ...            NaN
