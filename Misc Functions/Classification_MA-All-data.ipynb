# %%
import pandas as pd
import glob
import numpy as np

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# %%
columns_to_load = [
     'location_key'
    , 'date'
    , 'place_id'
    , 'wikidata_id' 
    , 'datacommons_id'
    , 'country_code'
    , 'country_name'
    , 'subregion1_code'
    , 'subregion1_name'
    , 'subregion2_code'
    , 'subregion2_name'
    , 'new_confirmed'
    , 'new_deceased'
    , 'cumulative_confirmed'
    , 'cumulative_deceased'
    , 'new_persons_fully_vaccinated'
    , 'cumulative_persons_fully_vaccinated'
    , 'population'
    , 'population_male'
    , 'population_female'
    , 'population_age_00_09'
    , 'population_age_10_19'
    , 'population_age_20_29'
    , 'population_age_30_39'
    , 'population_age_40_49'
    , 'population_age_50_59'
    , 'population_age_60_69'
    , 'population_age_70_79'
    , 'population_age_80_and_older'
    , 'openstreetmap_id'
    , 'latitude'
    , 'longitude'
    , 'area_sq_km'
    , 'life_expectancy'
    , 'mobility_retail_and_recreation'
    , 'mobility_grocery_and_pharmacy'
    , 'mobility_parks'
    , 'mobility_transit_stations'
    , 'mobility_workplaces'
    , 'mobility_residential'
    , 'average_temperature_celsius'
    , 'minimum_temperature_celsius'
    , 'maximum_temperature_celsius'
    , 'rainfall_mm'
    , 'dew_point'
    , 'relative_humidity'
]

# %%
# Directory path to your CSV files
directory_path = "../All CSVs/"  # Example directory path

# Initialize an empty DataFrame to store data from all CSV files
full_df = pd.DataFrame(columns=columns_to_load)

# Loop over the list of CSV files
for file in glob.glob(directory_path + '*.csv'):
    # Read the CSV file without specifying columns to ensure we don't miss any data
    df = pd.read_csv(file)
    
    # Ensure all desired columns are present, add them with NaN values if they are missing
    for column in columns_to_load:
        if column not in df.columns:
            df[column] = np.nan

    # Reorder and select only the desired columns to maintain consistency
    df = df[columns_to_load]
    
    # Append the contents of the file to the full DataFrame
    full_df = pd.concat([full_df, df], ignore_index=True)

# Optionally, reset the index of the final DataFrame
full_df.reset_index(drop=True, inplace=True)
# Out:
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_55407/3811379714.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_55407/3811379714.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_55407/3811379714.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)

# %%
# Print each column name
for column in df.columns:
    print(column)
# Out:
# location_key
# date
# place_id
# wikidata_id
# datacommons_id
# country_code
# country_name
# subregion1_code
# subregion1_name
# subregion2_code
# subregion2_name
# new_confirmed
# new_deceased
# cumulative_confirmed
# cumulative_deceased
# new_persons_fully_vaccinated
# cumulative_persons_fully_vaccinated
# population
# population_male
# population_female
# population_age_00_09
# population_age_10_19
# population_age_20_29
# population_age_30_39
# population_age_40_49
# population_age_50_59
# population_age_60_69
# population_age_70_79
# population_age_80_and_older
# openstreetmap_id
# latitude
# longitude
# area_sq_km
# life_expectancy
# mobility_retail_and_recreation
# mobility_grocery_and_pharmacy
# mobility_parks
# mobility_transit_stations
# mobility_workplaces
# mobility_residential
# average_temperature_celsius
# minimum_temperature_celsius
# maximum_temperature_celsius
# rainfall_mm
# dew_point
# relative_humidity

# %%
full_df.shape
# Out:
# (3196966, 46)

# %%
full_df.head(20)
# Out:
#    location_key        date                     place_id wikidata_id  \
# 0   US_TN_47015  2020-01-01  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
#
# 0                  1141                         582          1848169
# 1                  1141                         582          1848169
# 2                  1141                         582          1848169
# 3                  1141                         582          1848169
# 4                  1141                         582          1848169
# 5                  1141                         582          1848169
# 6                  1141                         582          1848169
# 7                  1141                         582          1848169
# 8                  1141                         582          1848169
# 9                  1141                         582          1848169
# 10                 1141                         582          1848169
# 11                 1141                         582          1848169
# 12                 1141                         582          1848169
# 13                 1141                         582          1848169
# 14                 1141                         582          1848169
# 15                 1141                         582          1848169
# 16                 1141                         582          1848169
# 17                 1141                         582          1848169
# 18                 1141                         582          1848169
# 19                 1141                         582          1848169
#
#     latitude  longitude area_sq_km  life_expectancy  \
# 0      35.81     -86.06        688             74.8
# 1      35.81     -86.06        688             74.8
# 2      35.81     -86.06        688             74.8
# 3      35.81     -86.06        688             74.8
# 4      35.81     -86.06        688             74.8
# 5      35.81     -86.06        688             74.8
# 6      35.81     -86.06        688             74.8
# 7      35.81     -86.06        688             74.8
# 8      35.81     -86.06        688             74.8
# 9      35.81     -86.06        688             74.8
# 10     35.81     -86.06        688             74.8
# 11     35.81     -86.06        688             74.8
# 12     35.81     -86.06        688             74.8
# 13     35.81     -86.06        688             74.8
# 14     35.81     -86.06        688             74.8
# 15     35.81     -86.06        688             74.8
# 16     35.81     -86.06        688             74.8
# 17     35.81     -86.06        688             74.8
# 18     35.81     -86.06        688             74.8
# 19     35.81     -86.06        688             74.8
#
#     mobility_retail_and_recreation  mobility_grocery_and_pharmacy  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                              NaN                            NaN
# 7                              NaN                            NaN
# 8                              NaN                            NaN
# 9                              NaN                            NaN
# 10                             NaN                            NaN
# 11                             NaN                            NaN
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
# 19                             NaN                            NaN
#
#     mobility_parks  mobility_transit_stations  mobility_workplaces  \
# 0              NaN                        NaN                  NaN
# 1              NaN                        NaN                  NaN
# 2              NaN                        NaN                  NaN
# 3              NaN                        NaN                  NaN
# 4              NaN                        NaN                  NaN
# 5              NaN                        NaN                  NaN
# 6              NaN                        NaN                  NaN
# 7              NaN                        NaN                  NaN
# 8              NaN                        NaN                  NaN
# 9              NaN                        NaN                  NaN
# 10             NaN                        NaN                  NaN
# 11             NaN                        NaN                  NaN
# 12             NaN                        NaN                  NaN
# 13             NaN                        NaN                  NaN
# 14             NaN                        NaN                  NaN
# 15             NaN                        NaN                  NaN
# 16             NaN                        NaN                  NaN
# 17             NaN                        NaN                  NaN
# 18             NaN                        NaN                  NaN
# 19             NaN                        NaN                  NaN
#
#     mobility_residential  average_temperature_celsius  \
# 0                    NaN                     3.604938
# 1                    NaN                     8.290123
# 2                    NaN                    11.691358
# 3                    NaN                     8.265432
# 4                    NaN                     3.160494
# 5                    NaN                     5.265432
# 6                    NaN                     7.574074
# 7                    NaN                     5.622222
# 8                    NaN                     6.105556
# 9                    NaN                    14.883333
# 10                   NaN                    16.977778
# 11                   NaN                     9.250000
# 12                   NaN                     7.450000
# 13                   NaN                    14.316667
# 14                   NaN                    15.872222
# 15                   NaN                    11.072222
# 16                   NaN                     3.272222
# 17                   NaN                     8.872222
# 18                   NaN                     3.061111
# 19                   NaN                    -5.716667
#
#     minimum_temperature_celsius  maximum_temperature_celsius  rainfall_mm  \
# 0                     -2.160494                    10.283951     0.028222
# 1                      4.728395                    10.345679     0.056444
# 2                      9.049383                    14.413580    14.336889
# 3                      2.265432                    13.790123     5.362222
# 4                     -2.500000                    11.432099     0.874889
# 5                     -2.308642                    12.987654     0.197556
# 6                      2.376543                    11.080247     0.931333
# 7                     -0.977778                    13.861111     0.660400
# 8                     -1.394444                    15.294444     0.050800
# 9                     13.038889                    17.561111     0.076200
# 10                    14.627778                    19.333333     1.041400
# 11                     5.711111                    15.833333    10.312400
# 12                     2.711111                    15.438889     0.025400
# 13                    10.944444                    16.483333     3.708400
# 14                    13.577778                    18.822222     3.276600
# 15                     6.505556                    18.188889     1.185333
# 16                     0.450000                     8.361111     0.101600
# 17                     5.488889                    12.405556     0.025400
# 18                    -2.294444                    12.150000     3.911600
# 19                    -7.266667                    -1.633333     0.330200
#
#     dew_point  relative_humidity
# 0   -4.277778          55.875991
# 1    2.062500          63.343321
# 2   11.361111          96.395122
# 3    5.784722          83.777328
# 4   -2.104167          67.714625
# 5   -0.708333          64.944304
# 6    0.187500          58.893798
# 7   -3.234568          52.538361
# 8   -2.481481          53.877994
# 9    7.586420          60.712606
# 10  14.629630          85.624504
# 11   6.154321          81.394451
# 12   5.131944          85.335970
# 13  12.567901          89.382793
# 14  14.888889          93.067113
# 15   6.808642          74.293859
# 16  -5.271605          52.722576
# 17   1.740741          59.461853
# 18  -5.006173          55.147280
# 19 -10.450617          68.183019

# %%
# List of interesting attributes
columns_of_interest = [
    'new_confirmed',
    'new_deceased',
    'mobility_retail_and_recreation',
    'mobility_grocery_and_pharmacy',
    'mobility_parks',
    'mobility_transit_stations',
    'mobility_workplaces',
    'mobility_residential',
    'average_temperature_celsius',
    'minimum_temperature_celsius',
    'maximum_temperature_celsius',
    'rainfall_mm',
    'dew_point',
    'relative_humidity'
]

# Filtering
filtered_df = full_df[columns_of_interest]

# Calculating the Pearson correlation matrix
correlation_matrix = filtered_df.corr()

# Applying a color gradient: blue to white to red
styled_corr = correlation_matrix.style.background_gradient(cmap='coolwarm', axis=None)

# Displaying the styled correlation matrix
styled_corr
# Out:
# <style type="text/css">
# #T_2c38e_row0_col0, #T_2c38e_row1_col1, #T_2c38e_row2_col2, #T_2c38e_row3_col3, #T_2c38e_row4_col4, #T_2c38e_row5_col5, #T_2c38e_row6_col6, #T_2c38e_row7_col7, #T_2c38e_row8_col8, #T_2c38e_row9_col9, #T_2c38e_row10_col10, #T_2c38e_row11_col11, #T_2c38e_row12_col12, #T_2c38e_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2c38e_row0_col1, #T_2c38e_row1_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_2c38e_row0_col2, #T_2c38e_row0_col4, #T_2c38e_row1_col3, #T_2c38e_row1_col6, #T_2c38e_row2_col0, #T_2c38e_row3_col1, #T_2c38e_row4_col0, #T_2c38e_row4_col11, #T_2c38e_row6_col1, #T_2c38e_row11_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_2c38e_row0_col3, #T_2c38e_row3_col0, #T_2c38e_row5_col13, #T_2c38e_row6_col9, #T_2c38e_row9_col6, #T_2c38e_row13_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_2c38e_row0_col5, #T_2c38e_row5_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_2c38e_row0_col6, #T_2c38e_row1_col4, #T_2c38e_row4_col1, #T_2c38e_row6_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_2c38e_row0_col7, #T_2c38e_row7_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_2c38e_row0_col8, #T_2c38e_row0_col9, #T_2c38e_row2_col11, #T_2c38e_row3_col11, #T_2c38e_row8_col0, #T_2c38e_row9_col0, #T_2c38e_row11_col2, #T_2c38e_row11_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_
col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_2c38e_row7_col12, #T_2c38e_row10_col13, #T_2c38e_row12_col7, #T_2c38e_row13_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_2c38e_row8_col9, #T_2c38e_row8_col10, #T_2c38e_row9_col8, #T_2c38e_row10_col8 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_2c38e_row8_col11, #T_2c38e_row11_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_2c38e_row8_col12, #T_2c38e_row12_col8 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_2c38e_row9_col10, #T_2c38e_row10_col9 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_2c38e_row9_col11, #T_2c38e_row11_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_2c38e_row9_col12, #T_2c38e_row12_col9 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_2c38e_row9_col13, #T_2c38e_row13_col9 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_2c38e_row10_col11, #T_2c38e_row11_col10 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_2c38e_row10_col12, #T_2c38e_row12_col10 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_2c38e_row11_col13, #T_2c38e_row13_col11 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# </style>
# <table id="T_2c38e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c38e_level0_col0" class="col_heading level0 col0" >new_confirmed</th>
#       <th id="T_2c38e_level0_col1" class="col_heading level0 col1" >new_deceased</th>
#       <th id="T_2c38e_level0_col2" class="col_heading level0 col2" >mobility_retail_and_recreation</th>
#       <th id="T_2c38e_level0_col3" class="col_heading level0 col3" >mobility_grocery_and_pharmacy</th>
#       <th id="T_2c38e_level0_col4" class="col_heading level0 col4" >mobility_parks</th>
#       <th id="T_2c38e_level0_col5" class="col_heading level0 col5" >mobility_transit_stations</th>
#       <th id="T_2c38e_level0_col6" class="col_heading level0 col6" >mobility_workplaces</th>
#       <th id="T_2c38e_level0_col7" class="col_heading level0 col7" >mobility_residential</th>
#       <th id="T_2c38e_level0_col8" class="col_heading level0 col8" >average_temperature_celsius</th>
#       <th id="T_2c38e_level0_col9" class="col_

# %%
import matplotlib.pyplot as plt

# Plot average temperature vs new confirmed cases
plot_data = full_df[['average_temperature_celsius', 'new_confirmed']]
plot_data.dropna(inplace=True)

# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(plot_data['average_temperature_celsius'], plot_data['new_confirmed'], alpha=0.5)

# Labels and title
plt.xlabel('Average Temperature (°C)')
plt.ylabel('New Confirmed Cases')
plt.title('Temperature vs. New COVID-19 Cases Across All Subregions')

# Show the plot
plt.show()
# Out:
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_55407/282663622.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data.dropna(inplace=True)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

#make a copy of the data
cluster1_df = full_df.copy()

# Data Preparation, normilization
cluster1_df['vaccination_rate'] = cluster1_df['cumulative_persons_fully_vaccinated'] / cluster1_df['population']
cluster1_df['death_rate'] = cluster1_df['new_deceased'] / cluster1_df['new_confirmed']
cluster1_df['confirmed_rate'] = cluster1_df['new_confirmed'] / cluster1_df['population']
cluster1_df['old_pop'] = (cluster1_df['population_age_50_59'] + cluster1_df['population_age_60_69']) / cluster1_df['population']

# Convert to numeric
numeric_columns = ['vaccination_rate', 'death_rate', 'confirmed_rate', 'old_pop']
for col in numeric_columns:
    cluster1_df[col] = pd.to_numeric(cluster1_df[col], errors='coerce')

# Drop NaN
cluster1_df = cluster1_df.dropna(subset=numeric_columns)

# Remove inifinity
cluster1_df = cluster1_df[np.isfinite(cluster1_df[numeric_columns]).all(axis=1)]

# Filter tiny rates
cluster1_df = cluster1_df[(cluster1_df['death_rate'] > 0.0000001) & (cluster1_df['confirmed_rate'] > 0.000001)]

# Threshold for 'new_deceased' binary target based on median
death_rate_threshold = cluster1_df['death_rate'].median()
cluster1_df['high_death_rate'] = (cluster1_df['death_rate'] > death_rate_threshold).astype(int)

# Features and target variable
features = ['vaccination_rate', 'old_pop']
target = 'high_death_rate'

# Split the dataset
X = cluster1_df[features]
y = cluster1_df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Building the Decision Tree
clf = DecisionTreeClassifier(max_depth=3, random_state=42)
clf.fit(X_train, y_train)

# Predict and Evaluate the Model
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Plot the Decision Tree
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=features, class_names=['Low', 'High'], filled=True)
plt.savefig('tree_high_res.png')
plt.show()
# Out:
# Accuracy: 0.6522797043774872
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67     22305
#            1       0.66      0.61      0.63     21670
#
#     accuracy                           0.65     43975
#    macro avg       0.65      0.65      0.65     43975
# weighted avg       0.65      0.65      0.65     43975

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns


#make a copy of the data
cluster2_df = full_df.copy()


# Filtering and normaliziation
cluster2_df['confirmed_per_capita'] = cluster2_df['new_confirmed'] / cluster2_df['population']
data = cluster2_df[['average_temperature_celsius', 'relative_humidity', 'confirmed_per_capita']]
data.dropna(inplace=True)  # Remove missing values

# Filter out small ratios
data = data[data['confirmed_per_capita'] >= 0.0001]


# Scale the Data, so no distance dependance...
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Clustering
# Choosing the number of clusters with the elbow method
inertias = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(data_scaled)
    inertias.append(kmeans.inertia_)

# Plotting the elbow plot
plt.figure(figsize=(8, 4))
plt.plot(range(1, 10), inertias, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# k=4
kmeans = KMeans(n_clusters=4, random_state=0)
clusters = kmeans.fit_predict(data_scaled)

# Analysis
data['Cluster'] = clusters

# Visualization
# 3D Scatter plot of Temperature vs. Humidity vs. Confirmed Cases per Capita colored by cluster
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(data['average_temperature_celsius'],
                     data['relative_humidity'],
                     data['confirmed_per_capita'],
                     c=data['Cluster'], cmap='viridis', s=100, alpha=0.6)
ax.set_xlabel('Average Temperature (Celsius)')
ax.set_ylabel('Relative Humidity (%)')
ax.set_zlabel('Confirmed Cases per Capita')
ax.set_title('3D Clusters by Temperature, Humidity, and COVID-19 Cases per Capita')
plt.legend(*scatter.legend_elements(), title='Cluster')
plt.show()

# Plot for Confirmed Cases per Capita by Cluster
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cluster', y='confirmed_per_capita', data=data)
plt.title('Confirmed Cases per Capita by Cluster')
plt.ylabel('Confirmed Cases per Capita')
plt.xlabel('Cluster')
plt.show()
# Out:
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_55407/4062371547.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)  # Remove missing values
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='average_temperature_celsius', 
    y='relative_humidity', 
    hue='Cluster', 
    data=data, 
    palette='bright',
    s=100, 
    alpha=0.5  
)
plt.title('Clusters by Temperature and Humidity')
plt.show()

# %%
# 2D projection of cluster 2
cluster_2_data = data[data['Cluster'] == 3]

# Plot the scatterplot for only cluster 2
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='average_temperature_celsius', 
    y='relative_humidity', 
    data=cluster_2_data,  # Use the filtered data
    color='orange',  # Choose a color that represents cluster 2
    s=100, 
    alpha=0.5  # Adjust transparency to 50%
)
plt.title('Cluster 3 by Temperature and Humidity')
plt.show()

# %% [markdown]
# end of the code :D
