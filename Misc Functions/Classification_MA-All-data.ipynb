# %%
import pandas as pd
import glob
import numpy as np

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# %%
columns_to_load = [
     'location_key'
    , 'date'
    , 'place_id'
    , 'wikidata_id'
    , 'datacommons_id'
    , 'country_code'
    , 'country_name'
    , 'subregion1_code'
    , 'subregion1_name'
    , 'subregion2_code'
    , 'subregion2_name'
    , 'new_confirmed'
    , 'new_deceased'
    , 'cumulative_confirmed'
    , 'cumulative_deceased'
    , 'new_persons_fully_vaccinated'
    , 'cumulative_persons_fully_vaccinated'
    , 'population'
    , 'population_male'
    , 'population_female'
    , 'population_age_00_09'
    , 'population_age_10_19'
    , 'population_age_20_29'
    , 'population_age_30_39'
    , 'population_age_40_49'
    , 'population_age_50_59'
    , 'population_age_60_69'
    , 'population_age_70_79'
    , 'population_age_80_and_older'
    , 'openstreetmap_id'
    , 'latitude'
    , 'longitude'
    , 'area_sq_km'
    , 'life_expectancy'
    , 'mobility_retail_and_recreation'
    , 'mobility_grocery_and_pharmacy'
    , 'mobility_parks'
    , 'mobility_transit_stations'
    , 'mobility_workplaces'
    , 'mobility_residential'
    , 'average_temperature_celsius'
    , 'minimum_temperature_celsius'
    , 'maximum_temperature_celsius'
    , 'rainfall_mm'
    , 'dew_point'
    , 'relative_humidity'
]

# %%
# Directory path to your CSV files
directory_path = "../All CSVs/"  # Example directory path

# Initialize an empty DataFrame to store data from all CSV files
full_df = pd.DataFrame(columns=columns_to_load)

# Loop over the list of CSV files
for file in glob.glob(directory_path + '*.csv'):
    # Read the CSV file without specifying columns to ensure we don't miss any data
    df = pd.read_csv(file)
    
    # Ensure all desired columns are present, add them with NaN values if they are missing
    for column in columns_to_load:
        if column not in df.columns:
            df[column] = np.nan

    # Reorder and select only the desired columns to maintain consistency
    df = df[columns_to_load]
    
    # Append the contents of the file to the full DataFrame
    full_df = pd.concat([full_df, df], ignore_index=True)

# Optionally, reset the index of the final DataFrame
full_df.reset_index(drop=True, inplace=True)
# Out:
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_8253/3811379714.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_8253/3811379714.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_8253/3811379714.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat([full_df, df], ignore_index=True)

# %%
# Print each column name
for column in df.columns:
    print(column)
# Out:
# location_key
# date
# place_id
# wikidata_id
# datacommons_id
# country_code
# country_name
# subregion1_code
# subregion1_name
# subregion2_code
# subregion2_name
# new_confirmed
# new_deceased
# cumulative_confirmed
# cumulative_deceased
# new_persons_fully_vaccinated
# cumulative_persons_fully_vaccinated
# population
# population_male
# population_female
# population_age_00_09
# population_age_10_19
# population_age_20_29
# population_age_30_39
# population_age_40_49
# population_age_50_59
# population_age_60_69
# population_age_70_79
# population_age_80_and_older
# openstreetmap_id
# latitude
# longitude
# area_sq_km
# life_expectancy
# mobility_retail_and_recreation
# mobility_grocery_and_pharmacy
# mobility_parks
# mobility_transit_stations
# mobility_workplaces
# mobility_residential
# average_temperature_celsius
# minimum_temperature_celsius
# maximum_temperature_celsius
# rainfall_mm
# dew_point
# relative_humidity

# %%
full_df.shape
# Out:
# (3198948, 46)

# %%
full_df.head(20)
# Out:
#    location_key        date                     place_id wikidata_id  \
# 0   US_TN_47015  2020-01-01  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 1   US_TN_47015  2020-01-02  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 2   US_TN_47015  2020-01-03  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 3   US_TN_47015  2020-01-04  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 4   US_TN_47015  2020-01-05  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 5   US_TN_47015  2020-01-06  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 6   US_TN_47015  2020-01-07  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 7   US_TN_47015  2020-01-08  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 8   US_TN_47015  2020-01-09  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 9   US_TN_47015  2020-01-10  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 10  US_TN_47015  2020-01-11  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 11  US_TN_47015  2020-01-12  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 12  US_TN_47015  2020-01-13  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 13  US_TN_47015  2020-01-14  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 14  US_TN_47015  2020-01-15  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 15  US_TN_47015  2020-01-16  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 16  US_TN_47015  2020-01-17  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 17  US_TN_47015  2020-01-18  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 18  US_TN_47015  2020-01-19  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
# 19  US_TN_47015  2020-01-20  ChIJlY6uZSRLYYgRxiQlGHwCm2s     Q494810
#
#    datacommons_id country_code              country_name subregion1_code  \
# 0     geoId/47015           US  United States of America              TN
# 1     geoId/47015           US  United States of America              TN
# 2     geoId/47015           US  United States of America              TN
# 3     geoId/47015           US  United States of America              TN
# 4     geoId/47015           US  United States of America              TN
# 5     geoId/47015           US  United States of America              TN
# 6     geoId/47015           US  United States of America              TN
# 2      35.81     -86.06        688             74.8
# 3      35.81     -86.06        688             74.8
# 4      35.81     -86.06        688             74.8
# 5      35.81     -86.06        688             74.8
# 6      35.81     -86.06        688             74.8
# 7      35.81     -86.06        688             74.8
# 8      35.81     -86.06        688             74.8
# 9      35.81     -86.06        688             74.8
# 10     35.81     -86.06        688             74.8
# 11     35.81     -86.06        688             74.8
# 12     35.81     -86.06        688             74.8
# 13     35.81     -86.06        688             74.8
# 14     35.81     -86.06        688             74.8
# 15     35.81     -86.06        688             74.8
# 16     35.81     -86.06        688             74.8
# 17     35.81     -86.06        688             74.8
# 18     35.81     -86.06        688             74.8
# 19     35.81     -86.06        688             74.8
#
#     mobility_retail_and_recreation  mobility_grocery_and_pharmacy  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                              NaN                            NaN
# 7                              NaN                            NaN
# 8                              NaN                            NaN
# 9                              NaN                            NaN
# 10                             NaN                            NaN
# 11                             NaN                            NaN
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
# 19                             NaN                            NaN
#
#     mobility_parks  mobility_transit_stations  mobility_workplaces  \
# 0              NaN                        NaN                  NaN
# 1              NaN                        NaN                  NaN
# 2              NaN                        NaN                  NaN
# 3              NaN                        NaN                  NaN
# 4              NaN                        NaN                  NaN
# 5              NaN                        NaN                  NaN
# 6              NaN                        NaN                  NaN
# 7              NaN                        NaN                  NaN
# 8              NaN                        NaN                  NaN
# 9              NaN                        NaN                  NaN
# 10             NaN                        NaN                  NaN
# 11             NaN                        NaN                  NaN
# 12             NaN                        NaN                  NaN
# 13             NaN                        NaN                  NaN
# 14             NaN                        NaN                  NaN
# 15             NaN                        NaN                  NaN
# 16             NaN                        NaN                  NaN
# 17             NaN                        NaN                  NaN
# 18             NaN                        NaN                  NaN
# 19             NaN                        NaN                  NaN
#
#     mobility_residential  average_temperature_celsius  \
# 0                    NaN                     3.604938
# 1                    NaN                     8.290123
# 2                    NaN                    11.691358
# 3                    NaN                     8.265432
# 4                    NaN                     3.160494
# 5                    NaN                     5.265432
# 6                    NaN                     7.574074
# 7                    NaN                     5.622222
# 8                    NaN                     6.105556
# 9                    NaN                    14.883333
# 10                   NaN                    16.977778
# 11                   NaN                     9.250000
# 12                   NaN                     7.450000
# 13                   NaN                    14.316667
# 14                   NaN                    15.872222
# 15                   NaN                    11.072222
# 16                   NaN                     3.272222
# 17                   NaN                     8.872222
# 18                   NaN                     3.061111
# 19                   NaN                    -5.716667
#
#     minimum_temperature_celsius  maximum_temperature_celsius  rainfall_mm  \
# 0                     -2.160494                    10.283951     0.028222
# 1                      4.728395                    10.345679     0.056444
# 2                      9.049383                    14.413580    14.336889
# 3                      2.265432                    13.790123     5.362222
# 4                     -2.500000                    11.432099     0.874889
# 5                     -2.308642                    12.987654     0.197556
# 6                      2.376543                    11.080247     0.931333
# 7                     -0.977778                    13.861111     0.660400
# 8                     -1.394444                    15.294444     0.050800
# 9                     13.038889                    17.561111     0.076200
# 10                    14.627778                    19.333333     1.041400
# 11                     5.711111                    15.833333    10.312400
# 12                     2.711111                    15.438889     0.025400
# 13                    10.944444                    16.483333     3.708400
# 14                    13.577778                    18.822222     3.276600
# 15                     6.505556                    18.188889     1.185333
# 16                     0.450000                     8.361111     0.101600
# 17                     5.488889                    12.405556     0.025400
# 18                    -2.294444                    12.150000     3.911600
# 19                    -7.266667                    -1.633333     0.330200
#
#     dew_point  relative_humidity
# 0   -4.277778          55.875991
# 1    2.062500          63.343321
# 2   11.361111          96.395122
# 3    5.784722          83.777328
# 4   -2.104167          67.714625
# 5   -0.708333          64.944304
# 6    0.187500          58.893798
# 7   -3.234568          52.538361
# 8   -2.481481          53.877994
# 9    7.586420          60.712606
# 10  14.629630          85.624504
# 11   6.154321          81.394451
# 12   5.131944          85.335970
# 13  12.567901          89.382793
# 14  14.888889          93.067113
# 15   6.808642          74.293859
# 16  -5.271605          52.722576
# 17   1.740741          59.461853
# 18  -5.006173          55.147280
# 19 -10.450617          68.183019

# %%
# List of attributes we are interested in
columns_of_interest = [
    'new_confirmed',
    'new_deceased',
    'mobility_retail_and_recreation',
    'mobility_grocery_and_pharmacy',
    'mobility_parks',
    'mobility_transit_stations',
    'mobility_workplaces',
    'mobility_residential',
    'average_temperature_celsius',
    'minimum_temperature_celsius',
    'maximum_temperature_celsius',
    'rainfall_mm',
    'dew_point',
    'relative_humidity'
]

# Filtering the DataFrame to include only the columns of interest
filtered_df = full_df[columns_of_interest]

# Calculating the Pearson correlation matrix
correlation_matrix = filtered_df.corr()

# Applying a color gradient: blue to white to red
styled_corr = correlation_matrix.style.background_gradient(cmap='coolwarm', axis=None)

# Displaying the styled correlation matrix
styled_corr
# Out:
# <style type="text/css">
# #T_73c13_row0_col0, #T_73c13_row1_col1, #T_73c13_row2_col2, #T_73c13_row3_col3, #T_73c13_row4_col4, #T_73c13_row5_col5, #T_73c13_row6_col6, #T_73c13_row7_col7, #T_73c13_row8_col8, #T_73c13_row9_col9, #T_73c13_row10_col10, #T_73c13_row11_col11, #T_73c13_row12_col12, #T_73c13_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_73c13_row0_col1, #T_73c13_row1_col0, #T_73c13_row4_col10, #T_73c13_row10_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_73c13_row0_col2, #T_73c13_row0_col4, #T_73c13_row1_col3, #T_73c13_row1_col6, #T_73c13_row2_col0, #T_73c13_row3_col1, #T_73c13_row4_col0, #T_73c13_row4_col11, #T_73c13_row6_col1, #T_73c13_row11_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_73c13_row0_col3, #T_73c13_row3_col0, #T_73c13_row5_col13, #T_73c13_row6_col9, #T_73c13_row9_col6, #T_73c13_row13_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T
{
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_73c13_row5_col7, #T_73c13_row7_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_73c13_row5_col8, #T_73c13_row8_col5, #T_73c13_row9_col13, #T_73c13_row13_col9 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_73c13_row5_col9, #T_73c13_row9_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_73c13_row6_col7, #T_73c13_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_73c13_row6_col11, #T_73c13_row11_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_73c13_row7_col8, #T_73c13_row8_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_73c13_row7_col9, #T_73c13_row9_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_73c13_row7_col10, #T_73c13_row10_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_73c13_row7_col11, #T_73c13_row11_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_73c13_row7_col12, #T_73c13_row10_col13, #T_73c13_row12_col7, #T_73c13_row13_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_73c13_row8_col9, #T_73c13_row8_col10, #T_73c13_row9_col8, #T_73c13_row10_col8 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_73c13_row8_col11, #T_73c13_row11_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_73c13_row8_col12, #T_73c13_row12_col8 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_73c13_row9_col10, #T_73c13_row10_col9 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_73c13_row9_col11, #T_73c13_row11_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_73c13_row9_col12, #T_73c13_row12_col9 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_73c13_row10_col11, #T_73c13_row11_col10 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_73c13_row10_col12, #T_73c13_row12_col10 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_73c13_row11_col13, #T_73c13_row13_col11 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# </style>
# <table id="T_73c13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73c13_level0_col0" class="col_heading level0 col0" >new_confirmed</th>
#       <th id="T_73c13_level0_col1" class="col_heading level0 col1" >new_deceased</th>
#       <th id="T_73c13_level0_col2" class="col_heading level0 col2" >mobility_retail_and_recreation</th>
#       <th id="T_73c13_level0_col3" class="col_heading level0 col3" >mobility_grocery_and_pharmacy</th>
#       <th id="T_73c13_level0_col4" class="col_heading level0 col4" >mobility_parks</th>
#       <th id="T_73c13_level0_col5" class="col_heading level0 col5" >mobility_transit_stations</th>
#       <th id="T_73c13_level0_col6" class="col_heading level0 col6" >mobility_workplaces</th>
#       <th id="T_73c13_level0_col7" class="col_heading level0 col7" >mobility_residential</th>
#       <th id="T_73c13_level0_col8" class="col_heading level0 col8" >average_temperature_celsius</th>
#       <th id="T_73c13_level0_col9" class="col_heading level0 col9" >minimum_temperature_celsius</th>
#       <th id="T_73c13_level0_col10" class="co

# %%
import matplotlib.pyplot as plt

# Select the necessary columns and drop rows with missing data
plot_data = full_df[['average_temperature_celsius', 'new_confirmed']]
plot_data.dropna(inplace=True)



# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(plot_data['average_temperature_celsius'], plot_data['new_confirmed'], alpha=0.5)

# Set plot labels and title
plt.xlabel('Average Temperature (°C)')
plt.ylabel('New Confirmed Cases')
plt.title('Temperature vs. New COVID-19 Cases Across All Subregions')

# Show the plot
plt.show()
# Out:
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_8253/3829399924.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data.dropna(inplace=True)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

cluster1_df = full_df.copy()

# Data Preparation
# Using direct column assignment to avoid future compatibility issues
cluster1_df['vaccination_rate'] = cluster1_df['cumulative_persons_fully_vaccinated'] / cluster1_df['population']
cluster1_df['death_rate'] = cluster1_df['new_deceased'] / cluster1_df['new_confirmed']
cluster1_df['confirmed_rate'] = cluster1_df['new_confirmed'] / cluster1_df['population']
cluster1_df['old_pop'] = (cluster1_df['population_age_50_59'] + cluster1_df['population_age_60_69']) / cluster1_df['population']

# Convert columns to numeric, ensuring there are no non-numeric types
numeric_columns = ['vaccination_rate', 'death_rate', 'confirmed_rate', 'old_pop']
for col in numeric_columns:
    cluster1_df[col] = pd.to_numeric(cluster1_df[col], errors='coerce')

# Drop NaN values safely
cluster1_df = cluster1_df.dropna(subset=numeric_columns)

# Ensure all rates are finite
cluster1_df = cluster1_df[np.isfinite(cluster1_df[numeric_columns]).all(axis=1)]

# Filter tiny rates
cluster1_df = cluster1_df[(cluster1_df['death_rate'] > 0.0000001) & (cluster1_df['confirmed_rate'] > 0.000001)]

# Define your threshold for 'new_deceased' to create a binary target
death_rate_threshold = cluster1_df['death_rate'].median()
cluster1_df['high_death_rate'] = (cluster1_df['death_rate'] > death_rate_threshold).astype(int)

# Select features and target variable
features = ['vaccination_rate', 'old_pop']
target = 'high_death_rate'

# Split the dataset
X = cluster1_df[features]
y = cluster1_df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Building the Decision Tree
clf = DecisionTreeClassifier(max_depth=3, random_state=42)
clf.fit(X_train, y_train)

# Predict and Evaluate the Model
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Plot the Decision Tree
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=features, class_names=['Low', 'High'], filled=True)
plt.savefig('tree_high_res.png')
plt.show()
# Out:
# Accuracy: 0.650737623314327
#               precision    recall  f1-score   support
#
#            0       0.65      0.67      0.66     22149
#            1       0.65      0.64      0.64     22047
#
#     accuracy                           0.65     44196
#    macro avg       0.65      0.65      0.65     44196
# weighted avg       0.65      0.65      0.65     44196

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
cluster2_df = full_df.copy()

# Load your data - assuming it's already loaded as cluster2_df

# Step 1: Data Preparation
# Filter out necessary columns and calculate new_confirmed per capita
cluster2_df['confirmed_per_capita'] = cluster2_df['new_confirmed'] / cluster2_df['population']
data = cluster2_df[['average_temperature_celsius', 'relative_humidity', 'confirmed_per_capita']]
data.dropna(inplace=True)  # Remove missing values

# Filter out small ratios, e.g., where confirmed_per_capita is less than 0.0001
data = data[data['confirmed_per_capita'] >= 0.0001]

# Step 2: Feature Selection is already done in Step 1 by filtering columns

# Step 3: Scaling the Data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Step 4: Clustering
# Choosing the number of clusters with the elbow method
inertias = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(data_scaled)
    inertias.append(kmeans.inertia_)

# Plotting the elbow plot
plt.figure(figsize=(8, 4))
plt.plot(range(1, 10), inertias, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# Let's assume the elbow point is at k=3
kmeans = KMeans(n_clusters=3, random_state=0)
clusters = kmeans.fit_predict(data_scaled)

# Step 5: Analysis
data['Cluster'] = clusters

# Step 6: Visualization
# 3D Scatter plot of Temperature vs. Humidity vs. Confirmed Cases per Capita colored by cluster
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(data['average_temperature_celsius'],
                     data['relative_humidity'],
                     data['confirmed_per_capita'],
                     c=data['Cluster'], cmap='viridis', s=100, alpha=0.6)
ax.set_xlabel('Average Temperature (Celsius)')
ax.set_ylabel('Relative Humidity (%)')
ax.set_zlabel('Confirmed Cases per Capita')
ax.set_title('3D Clusters by Temperature, Humidity, and COVID-19 Cases per Capita')
plt.legend(*scatter.legend_elements(), title='Cluster')
plt.show()

# Plot for Confirmed Cases per Capita by Cluster
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cluster', y='confirmed_per_capita', data=data)
plt.title('Confirmed Cases per Capita by Cluster')
plt.ylabel('Confirmed Cases per Capita')
plt.xlabel('Cluster')
plt.show()
# Out:
# /var/folders/t4/lfsjh9xn283d3_fxmgbd1mjr0000gn/T/ipykernel_8253/4112565732.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)  # Remove missing values
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 62
#      60 ax.set_title('3D Clusters by Temperature, Humidity, and COVID-19 Cases per Capita')
#      61 plt.legend(*scatter.legend_elements(), title='Cluster')
# ---> 62 plt.show()
#      64 # Plot for Confirmed Cases per Capita by Cluster
#      65 plt.figure(figsize=(10, 6))
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File /opt/anaconda3/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File /opt/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File /opt/anaconda3/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File /opt/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File /opt/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2187, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2183 try:
#    2184     # _get_renderer may change the figure dpi (as vector formats
#    2185     # force the figure dpi to 72), so we need to set it again here.
#    2186     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2187         result = print_method(
#    2188             filename,
#    2189             facecolor=facecolor,
#    2190             edgecolor=edgecolor,
#    2191             orientation=orientation,
#    2192             bbox_inches_restore=_bbox_inches_restore,
#    2193             **kwargs)
#    2194 finally:
#    2195     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     441     """
#     442     Draw the canvas, then save it using `.image.imsave` (to which
#     443     *pil_kwargs* and *metadata* are forwarded).
#     444     """
# --> 445     FigureCanvasAgg.draw(self)
#     446     mpl.image.imsave(
#     447         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py:497, in Axes3D.draw(self, renderer)
#     494         axis.draw(renderer)
#     496 # Then rest
# --> 497 super().draw(renderer)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py:670, in Path3DCollection.draw(self, renderer)
#     668 with self._use_zordered_offset():
#     669     with cbook._setattr_cm(self, _in_draw=True):
# --> 670         super().draw(renderer)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:1005, in _CollectionWithSizes.draw(self, renderer)
#    1002 @artist.allow_rasterization
#    1003 def draw(self, renderer):
#    1004     self.set_sizes(self._sizes, self.figure.dpi)
# -> 1005     super().draw(renderer)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:378, in Collection.draw(self, renderer)
#     371 # If the collection is made up of a single shape/color/stroke,
#     372 # it can be rendered once and blitted multiple times, using
#     373 # `draw_markers` rather than `draw_path_collection`.  This is
#     374 # *much* faster for Agg, and results in smaller file sizes in
#     375 # PDF/SVG/PS.
#     377 trans = self.get_transforms()
# --> 378 facecolors = self.get_facecolor()
#     379 edgecolors = self.get_edgecolor()
#     380 do_single_path_optimization = False
#
# File /opt/anaconda3/lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py:806, in Path3DCollection.get_facecolor(self)
#     805 def get_facecolor(self):
# --> 806     return self._maybe_depth_shade_and_sort_colors(super().get_facecolor())
#
# File /opt/anaconda3/lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py:803, in Path3DCollection._maybe_depth_shade_and_sort_colors(self, color_array)
#     801 if len(color_array) > 1:
#     802     color_array = color_array[self._z_markers_idx]
# --> 803 return mcolors.to_rgba_array(color_array, self._alpha)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/colors.py:505, in to_rgba_array(c, alpha)
#     503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
# --> 505     rgba = np.array([to_rgba(cc) for cc in c])
#     507 if alpha is not None:
#     508     rgba[:, 3] = alpha
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/colors.py:505, in <listcomp>(.0)
#     503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
# --> 505     rgba = np.array([to_rgba(cc) for cc in c])
#     507 if alpha is not None:
#     508     rgba[:, 3] = alpha
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/ma/core.py:3271, in MaskedArray.__getitem__(self, indx)
#    3266     scalar_expected = _scalar_heuristic(self.data, dout)
#    3267     if scalar_expected is None:
#    3268         # heuristics have failed
#    3269         # construct a full array, so we can be certain. This is costly.
#    3270         # we could also fall back on ndarray.__getitem__(self.data, indx)
# -> 3271         scalar_expected = _is_scalar(getmaskarray(self)[indx])
#    3273 # Did we extract a single item?
#    3274 if scalar_expected:
#    3275     # A record
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/ma/core.py:1473, in getmaskarray(arr)
#    1471 mask = getmask(arr)
#    1472 if mask is nomask:
# -> 1473     mask = make_mask_none(np.shape(arr), getattr(arr, 'dtype', None))
#    1474 return mask
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/ma/core.py:1690, in make_mask_none(newshape, dtype)
#    1688     result = np.zeros(newshape, dtype=MaskType)
#    1689 else:
# -> 1690     result = np.zeros(newshape, dtype=make_mask_descr(dtype))
#    1691 return result
#
# KeyboardInterrupt:

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# Load your data - assuming it's already loaded as cluster2_df

# Step 1: Data Preparation
# Filter out necessary columns and calculate new_confirmed per capita
cluster2_df['confirmed_per_capita'] = cluster2_df['new_confirmed'] / cluster2_df['population']
data = cluster2_df[['average_temperature_celsius', 'relative_humidity', 'confirmed_per_capita', 'new_confirmed']]
data.dropna(inplace=True)  # Remove missing values

# Filter out small ratios, e.g., where confirmed_per_capita is less than 0.0001
data = data[data['confirmed_per_capita'] >= 0.0001]

# Step 2: Feature Selection is already done in Step 1 by filtering columns

# Step 3: Scaling the Data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data[['average_temperature_celsius', 'relative_humidity', 'confirmed_per_capita']])

# Step 4: Clustering
# Choosing the number of clusters with the elbow method
inertias = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(data_scaled)
    inertias.append(kmeans.inertia_)

# Plotting the elbow plot
plt.figure(figsize=(8, 4))
plt.plot(range(1, 10), inertias, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# Let's assume the elbow point is at k=3
kmeans = KMeans(n_clusters=3, random_state=0)
clusters = kmeans.fit_predict(data_scaled)

# Step 5: Analysis
data['Cluster'] = clusters

# Visualization: Total Confirmed Cases by Cluster
cluster_confirmed_totals = data.groupby('Cluster')['new_confirmed'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Cluster', y='new_confirmed', data=cluster_confirmed_totals)
plt.title('Total Confirmed Cases by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Total Confirmed Cases')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='average_temperature_celsius', 
    y='relative_humidity', 
    hue='Cluster', 
    data=data, 
    palette='bright', # This changes the color palette to a brighter one
    s=100, 
    alpha=0.5  # This changes the transparency to 50%
)
plt.title('Clusters by Temperature and Humidity')
plt.show()

# %%
# Filter the DataFrame to include only the rows where the cluster label is 2
cluster_2_data = data[data['Cluster'] == 1]

# Plot the scatterplot for only cluster 2
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='average_temperature_celsius', 
    y='relative_humidity', 
    data=cluster_2_data,  # Use the filtered data
    color='orange',  # Choose a color that represents cluster 2
    s=100, 
    alpha=0.5  # Adjust transparency to 50%
)
plt.title('Cluster 2 by Temperature and Humidity')
plt.show()
